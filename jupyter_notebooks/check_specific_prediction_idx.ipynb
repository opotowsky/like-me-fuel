# %%
import pandas as pd

# %%
burn = pd.read_csv('../results/19jan2020_15nuc/15nuc_m100_burnup_predictions.csv')
rxtr = pd.read_csv('../results/19jan2020_15nuc/15nuc_m100_reactor_predictions.csv')

# %%
burn.head()
# Out:
#    Unnamed: 0     ba136     ba138     cs133     cs134     cs135     cs137  \
# 0           0 -0.863067 -1.415945 -1.565003 -0.779322 -1.345391 -1.397918
# 1           1 -0.858772 -1.300283 -1.441757 -0.776029 -1.266153 -1.280992
# 2           2 -0.858718 -1.300188 -1.440271 -0.776029 -1.264684 -1.280992
# 3           3 -0.858672 -1.300188 -1.439025 -0.776031 -1.263683 -1.280992
# 4           4 -0.858134 -1.300188 -1.426968 -0.776053 -1.262749 -1.281054
#
#       eu153     eu154     pu239     pu240     pu241     pu242     sm149  \
# 0 -1.210150 -0.973977 -2.607959 -1.968287 -1.287027 -0.912937 -3.019493
# 1 -1.177693 -0.969287 -2.113654 -1.905938 -1.284308 -0.912892 -1.354019
# 2 -1.177317 -0.969288 -2.107895 -1.905938 -1.284308 -0.912892 -1.156396
# 3 -1.177065 -0.969288 -2.103672 -1.905938 -1.284309 -0.912892 -1.010531
# 4 -1.175872 -0.969295 -2.080828 -1.905938 -1.284312 -0.912892 -0.263819
#
#       sm150     sm152    TrueY          kNN    DTree          SVR
# ...

# %%
burn.loc[burn['Unnamed: 0'] == 5010, :]
# Out:
#       Unnamed: 0   ba136     ba138     cs133     cs134     cs135     cs137  \
# 5010        5010  0.3866  0.683742  0.793503  0.543715  0.600502  0.759751
#
#          eu153     eu154     pu239     pu240     pu241     pu242     sm149  \
# 5010  0.833593  1.004706  1.083491  0.823368  1.458144  0.678211  1.757418
#
#          sm150     sm152    TrueY           kNN    DTree           SVR
# 5010  0.828404  0.724341  39382.5  39318.003372  39382.5  39385.684405

# %%
rxtr.loc[rxtr['Unnamed: 0'] == 5010, :]
# Out:
#       Unnamed: 0   ba136     ba138     cs133     cs134     cs135     cs137  \
# 5010        5010  0.3866  0.683742  0.793503  0.543715  0.600502  0.759751
#
#          eu153     eu154     pu239     pu240     pu241     pu242     sm149  \
# 5010  0.833593  1.004706  1.083491  0.823368  1.458144  0.678211  1.757418
#
#          sm150     sm152 TrueY  kNN DTree  SVR
# 5010  0.828404  0.724341   pwr  pwr   pwr  pwr
