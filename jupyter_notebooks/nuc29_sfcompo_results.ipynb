# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
# %matplotlib inline

# %% [markdown]
# # Data Setup & Functions

# %%
from mll_calc.mll_pred import format_XY, convert_g_to_mgUi

# %%
def logpdf_calc(row, test_sample, unc):
    y_sim = row[test_sample>0].values.tolist()
    std = row.multiply(unc)[test_sample>0].values.tolist()
    y_mes = test_sample[test_sample>0].values.tolist()
    logpdf_list = stats.norm.logpdf(y_sim, loc=y_mes, scale=std)
    return logpdf_list

# %%
def loop_sfco(XY, test, pred, unc, lbls, nonlbls):
    xy_cols = XY.columns.tolist()
    for col in nonlbls: xy_cols.remove(col)
    test = test[xy_cols]
    
    logpdf_df = pd.DataFrame()
    for test_idx, row in test.iterrows():
        test_sample = row.drop(lbls)
        test_answer = row[lbls]
        pred_row = pred.loc[pred['sim_idx'] == test_idx]
        pred_idx = pred_row['pred_idx'].values[0]
        train_row = XY.loc[pred_idx].drop(lbls+nonlbls)
        
        logpdf = logpdf_calc(train_row, test_sample, unc)
        mll = pred_row['MaxLogLL'].values[0]
        
        if round(mll, 4) != round(np.sum(logpdf), 4):
            print('mismatch')
            break
        
        logpdf = pd.Series(logpdf, index=train_row[test_sample>0].index, name=test_idx)
        if logpdf_df.empty:
            logpdf_df = pd.DataFrame(columns = test_sample.index.to_list())
        logpdf_df = logpdf_df.append(logpdf)
    return logpdf_df

# %% [markdown]
# ### Train and Test DBs

# %%
lbls = ['ReactorType', 'CoolingTime', 'Enrichment', 'Burnup', 'OrigenReactor']
nonlbls = ['AvgPowerDensity', 'ModDensity', 'UiWeight']

train_pkl = '~/sims_n_results/simupdates_aug2020/not-scaled_nuc29.pkl'
XY = format_XY(train_pkl)
XY = convert_g_to_mgUi(XY, lbls+nonlbls)

sfco_pkl = '~/sfcompo/format_clean/sfcompo_nuc29.pkl'
sfco = pd.read_pickle(sfco_pkl)

# %% [markdown]
# ### LL Calc Results

# %%
sfcompo_results = '~/sims_n_results/simupdates_aug2020/sfco29/'

uncs = [0.05, 0.1, 0.15, 0.2]
job_dirs = ['Job' + str(i) + '_unc' + str(unc) for i, unc in enumerate(uncs)]
dfs = {}
for i, unc_job in enumerate(job_dirs):
    dfs['unc' + str(i)] = pd.read_csv(sfcompo_results + unc_job + '/' + unc_job + '.csv')

for dfname in list(dfs.keys()):
    df = dfs[dfname]
    df['Relative_Burnup_Error'] = df['Burnup_Error'] / df['Burnup']
    df['Relative_Enrichment_Error'] = df['Enrichment_Error'] / df['Enrichment']

# For ease of only viewing 5% case for now
preds = dfs['unc0']

# %% [markdown]
# ### LogPDF (wrt nuclide) results

# %%
unc = 0.05
logpdf_df = loop_sfco(XY, sfco, preds, unc, lbls, nonlbls)

# %% [markdown]
# # Explore Errors

# %% [markdown]
# ### Burnup

# %%
preds['Relative_Burnup_Error'].describe()
#nuc15 results for reference:
#count    505.000000
#mean       0.187539
#std        0.155398
#min        0.000408
#25%        0.058485
#50%        0.153846
#75%        0.298556
#max        1.503097
# Out:
# count    505.000000
# mean       0.151887
# std        0.195778
# min        0.000031
# 25%        0.036301
# 50%        0.087295
# 75%        0.183161
# max        1.440513
# Name: Relative_Burnup_Error, dtype: float64

# %%
to_print = ['sim_idx', 'pred_idx', 'pred_CoolingTime', 'AvgPowerDensity', 
            'ReactorType', 'pred_ReactorType', 'ReactorType_Score', 
            'Enrichment', 'pred_Enrichment', 'Relative_Enrichment_Error', 
            'Burnup', 'pred_Burnup', 'Relative_Burnup_Error',
            'OrigenReactor', 'pred_OrigenReactor', 'MaxLogLL']
preds.loc[preds['Relative_Burnup_Error'] > 0.49, to_print]
# Out:
#                        sim_idx  pred_idx  pred_CoolingTime  AvgPowerDensity  \
# 54           GAR-1|SA-13|E6|11    111254       1136.709042             10.0
# 55           GAR-1|SA-13|E6|13     50762          0.826167             10.0
# 56            GAR-1|SA-13|E6|1    175085        109.336506             25.0
# 57           GAR-1|SA-13|E6|16     40811        829.867541             10.0
# 58           GAR-1|SA-13|E6|10    239103          8.087540             20.0
# 60            GAR-1|SA-13|E6|7     59347        334.379204             25.0
# 61            GAR-1|SA-13|E6|5    171906        242.633977             10.0
# 62            GAR-1|A-106|D4|1     41044         25.487227             10.0
# 63            GAR-1|A-106|E5|1    309124         29.215503             41.0
# 64            GAR-1|A-106|C3|1    232501          0.462278             10.0
# 65            GAR-1|A-106|D2|1    173820          0.000602             20.0
# 66            GAR-1|A-106|B1|1     46140          0.000710             10.0
# 67            GAR-1|A-106|B2|1     54540          0.000710             25.0
# 68            GAR-1|A-106|A3|1     42780          0.000710             20.0
# 69            GAR-1|A-106|G7|1    173820          0.000602             20.0
# 70            GAR-1|A-106|A5|1     56221          0.504127             10.0
# 72            GAR-1|A-106|C1|1     54540          0.000710             25.0
# 74            GAR-1|A-106|H2|1    173940          0.000602             20.0
# 76            GAR-1|A-106|H8|1     42844         25.487227             20.0
# 110  JPD-1|A-20|C3|KA-1040+660    211878       1555.867201             10.0
# 236             NPD-1|1022|A|1    362337       6777.780883             22.0
# 363        TVC-1|509-069|E11|1    222665        101.346301             10.0
# 374         TVC-1|509-069|E5|9    172442          1.002610             10.0
# 375        TVC-1|509-069|E11|9    172440          0.000602             10.0
# 376        TVC-1|509-069|E11|2    172502          1.002610             10.0
# 378        TVC-1|509-069|E11|4    172562          1.002610             10.0
# 380         TVC-1|509-069|E5|4    172562          1.002610             10.0
# 382        TVC-1|509-069|E11|7    172624         22.729917             10.0
# 384         TVC-1|509-069|L5|4    172562          1.002610             10.0
# 386        TVC-1|509-069|E11|5    172624         22.729917             10.0
# 387         TVC-1|509-069|L5|7    172624         22.729917             10.0
# 388        TVC-1|509-069|L11|7    172561          0.354806             10.0
# 390         TVC-1|509-069|E5|7    172562          1.002610             10.0
# 392         TVC-1|509-069|J9|4    172561          0.354806             10.0
#
#     ReactorType pred_ReactorType  ReactorType_Score  Enrichment  \
# 54          bwr              bwr               True       2.410
# 55          bwr              bwr               True       2.410
# 56          bwr              bwr               True       2.410
# 57          bwr              bwr               True       2.410
# 58          bwr              bwr               True       2.410
# 60          bwr              bwr               True       2.410
# 61          bwr              bwr               True       2.410
# 62          bwr              bwr               True       2.100
# 63          bwr              pwr              False       2.100
# 64          bwr              bwr               True       2.100
# 65          bwr              bwr               True       2.100
# 66          bwr              bwr               True       1.600
# 67          bwr              bwr               True       2.100
# 68          bwr              bwr               True       2.100
# 69          bwr              bwr               True       2.100
# 70          bwr              bwr               True       2.100
# 72          bwr              bwr               True       2.100
# 74          bwr              bwr               True       2.100
# 76          bwr              bwr               True       2.100
# 110         bwr              bwr               True       2.600
# 236        phwr             phwr               True       0.711
# 363         pwr              bwr              False       3.130
# 374         pwr              bwr              False       3.130
# 375         pwr              bwr              False       3.130
# 376         pwr              bwr              False       3.130
# 378         pwr              bwr              False       3.130
# 380         pwr              bwr              False       3.130
# 382         pwr              bwr              False       3.130
# 384         pwr              bwr              False       3.130
# 386         pwr              bwr              False       3.130
# 387         pwr              bwr              False       3.130
# 388         pwr              bwr              False       3.130
# 390         pwr              bwr              False       3.130
# 392         pwr              bwr              False       3.130
#
#      pred_Enrichment  Relative_Enrichment_Error   Burnup  pred_Burnup  \
# 54             5.230                   1.170124   4200.0      8683.04
# 55             4.570                   0.896266   5580.0      9758.61
# 56             5.110                   1.120332   6080.0      9304.01
# 57             4.400                   0.825726   6640.0     11427.93
# 58             5.050                   1.095436   8140.0     13912.97
# 60             4.570                   0.896266   8320.0     13478.85
# 61             5.110                   1.120332   8640.0     13992.11
# 62             4.400                   1.095238   8850.0     17668.74
# 63             5.480                   1.609524   8930.0     21793.78
# 64             5.050                   1.404762   9140.0     17118.70
# 65             5.110                   1.433333   9440.0     19593.53
# 66             4.400                   1.750000   9800.0     19250.15
# 67             4.570                   1.176190  10280.0     19250.15
# 68             4.400                   1.095238  10510.0     19250.15
# 69             5.110                   1.433333  10540.0     19593.53
# 70             4.570                   1.176190  10570.0     19250.15
# 72             4.570                   1.176190  10660.0     19250.15
# 74             5.110                   1.433333  11920.0     21847.13
# 76             4.400                   1.095238  12700.0     21745.58
# 110            2.730                   0.050000   2679.0      4283.63
# 236            0.711                   0.000000    791.0      1226.94
# 363            4.070                   0.300319  12859.0     22741.40
# 374            5.110                   0.632588  19254.0     31029.09
# 375            5.110                   0.632588  20060.0     31029.09
# 376            5.110                   0.632588  20628.0     33252.52
# 378            5.110                   0.632588  23557.0     39461.41
# 380            5.110                   0.632588  23715.0     39461.41
# 382            5.110                   0.632588  23953.0     43096.56
# 384            5.110                   0.632588  23988.0     39461.41
# 386            5.110                   0.632588  24250.0     43096.56
# 387            5.110                   0.632588  24313.0     43096.56
# 388            5.110                   0.632588  24532.0     39461.41
# 390            5.110                   0.632588  24693.0     39461.41
# 392            5.110                   0.632588  24849.0     39461.41
#
#      Relative_Burnup_Error                                OrigenReactor  \
# 54                1.067390                             Garigliano-1_BWR
# 55                0.748855                             Garigliano-1_BWR
# 56                0.530265                             Garigliano-1_BWR
# 57                0.721074                             Garigliano-1_BWR
# 58                0.709210                             Garigliano-1_BWR
# 60                0.620054                             Garigliano-1_BWR
# 61                0.619457                             Garigliano-1_BWR
# 62                0.996468                             Garigliano-1_BWR
# 63                1.440513                             Garigliano-1_BWR
# 64                0.872943                             Garigliano-1_BWR
# 65                1.075586                             Garigliano-1_BWR
# 66                0.964301                             Garigliano-1_BWR
# 67                0.872583                             Garigliano-1_BWR
# 68                0.831603                             Garigliano-1_BWR
# 69                0.858969                             Garigliano-1_BWR
# 70                0.821206                             Garigliano-1_BWR
# 72                0.805830                             Garigliano-1_BWR
# 74                0.832813                             Garigliano-1_BWR
# 76                0.712250                             Garigliano-1_BWR
# 110               0.598966      Japan Power Demonstration Reactor-1_BWR
# 236               0.551125  Nuclear Power Demonstration Reactor-1_CANDU
# 363               0.768520                       Trino Vercellese-1_PWR
# 374               0.611566                       Trino Vercellese-1_PWR
# 375               0.546814                       Trino Vercellese-1_PWR
# 376               0.612009                       Trino Vercellese-1_PWR
# 378               0.675146                       Trino Vercellese-1_PWR
# 380               0.663985                       Trino Vercellese-1_PWR
# 382               0.799213                       Trino Vercellese-1_PWR
# 384               0.645048                       Trino Vercellese-1_PWR
# 386               0.777178                       Trino Vercellese-1_PWR
# 387               0.772573                       Trino Vercellese-1_PWR
# 388               0.608569                       Trino Vercellese-1_PWR
# 390               0.598081                       Trino Vercellese-1_PWR
# 392               0.588048                       Trino Vercellese-1_PWR
#
#     pred_OrigenReactor     MaxLogLL
# 54            abb8x8-1    -8.741122
# 55             ge7x7-0    11.544400
# 56       atrium10x10-9    10.778134
# 57             ge7x7-0    -8.061510
# 58            svea64-1    23.738365
# 60             ge7x7-0    23.983706
# 61       atrium10x10-9     3.973372
# 62             ge7x7-0  -449.234902
# 63              s18x18  -516.102948
# 64            svea64-1  -491.230270
# 65       atrium10x10-9  -407.161465
# 66             ge7x7-0  -557.013513
# 67             ge7x7-0  -406.768373
# 68             ge7x7-0  -364.540287
# 69       atrium10x10-9  -357.078066
# 70             ge7x7-0  -343.471538
# 72             ge7x7-0  -405.010821
# 74       atrium10x10-9  -375.214868
# 76             ge7x7-0  -373.852508
# 110           svea64-1 -1031.807172
# 236            candu28   -89.248157
# 363           svea64-1  -445.065092
# 374      atrium10x10-9  -305.349660
# 375      atrium10x10-9  -280.085416
# 376      atrium10x10-9  -322.045123
# 378      atrium10x10-9  -289.601189
# 380      atrium10x10-9  -298.673021
# 382      atrium10x10-9  -463.506313
# 384      atrium10x10-9  -356.795039
# 386      atrium10x10-9  -527.044231
# 387      atrium10x10-9  -465.490489
# 388      atrium10x10-9  -307.556994
# 390      atrium10x10-9  -349.871603
# 392      atrium10x10-9  -269.413317

# %% [markdown]
# ### Enrichment

# %%
preds['Relative_Enrichment_Error'].describe()
#nuc15 results for reference:
#count    505.000000
#mean       0.369961
#std        0.289978
#min        0.000000
#25%        0.119444
#50%        0.288235
#75%        0.611765
#max        2.853727
# Out:
# count    505.000000
# mean       0.165083
# std        0.248423
# min        0.000000
# 25%        0.047923
# 50%        0.083004
# 75%        0.170455
# max        1.750000
# Name: Relative_Enrichment_Error, dtype: float64

# %%
preds.loc[preds['Relative_Enrichment_Error'] > 0.49, to_print]
# Out:
#                  sim_idx  pred_idx  pred_CoolingTime  AvgPowerDensity  \
# 54     GAR-1|SA-13|E6|11    111254       1136.709042             10.0
# 55     GAR-1|SA-13|E6|13     50762          0.826167             10.0
# 56      GAR-1|SA-13|E6|1    175085        109.336506             25.0
# 57     GAR-1|SA-13|E6|16     40811        829.867541             10.0
# 58     GAR-1|SA-13|E6|10    239103          8.087540             20.0
# 59      GAR-1|SA-13|E6|3    165126        242.633977             25.0
# 60      GAR-1|SA-13|E6|7     59347        334.379204             25.0
# 61      GAR-1|SA-13|E6|5    171906        242.633977             10.0
# 62      GAR-1|A-106|D4|1     41044         25.487227             10.0
# 63      GAR-1|A-106|E5|1    309124         29.215503             41.0
# 64      GAR-1|A-106|C3|1    232501          0.462278             10.0
# 65      GAR-1|A-106|D2|1    173820          0.000602             20.0
# 66      GAR-1|A-106|B1|1     46140          0.000710             10.0
# 67      GAR-1|A-106|B2|1     54540          0.000710             25.0
# 68      GAR-1|A-106|A3|1     42780          0.000710             20.0
# 69      GAR-1|A-106|G7|1    173820          0.000602             20.0
# 70      GAR-1|A-106|A5|1     56221          0.504127             10.0
# 72      GAR-1|A-106|C1|1     54540          0.000710             25.0
# 74      GAR-1|A-106|H2|1    173940          0.000602             20.0
# 76      GAR-1|A-106|H8|1     42844         25.487227             20.0
# 78      GAR-1|A-106|A9|1    219180          0.000619             20.0
# 303   QC-1|LYD396|C7|C1B    112398       1603.365247             10.0
# 374   TVC-1|509-069|E5|9    172442          1.002610             10.0
# 375  TVC-1|509-069|E11|9    172440          0.000602             10.0
# 376  TVC-1|509-069|E11|2    172502          1.002610             10.0
# 378  TVC-1|509-069|E11|4    172562          1.002610             10.0
# 380   TVC-1|509-069|E5|4    172562          1.002610             10.0
# 382  TVC-1|509-069|E11|7    172624         22.729917             10.0
# 384   TVC-1|509-069|L5|4    172562          1.002610             10.0
# 386  TVC-1|509-069|E11|5    172624         22.729917             10.0
# 387   TVC-1|509-069|L5|7    172624         22.729917             10.0
# 388  TVC-1|509-069|L11|7    172561          0.354806             10.0
# 390   TVC-1|509-069|E5|7    172562          1.002610             10.0
# 392   TVC-1|509-069|J9|4    172561          0.354806             10.0
#
#     ReactorType pred_ReactorType  ReactorType_Score  Enrichment  \
# 54          bwr              bwr               True        2.41
# 55          bwr              bwr               True        2.41
# 56          bwr              bwr               True        2.41
# 57          bwr              bwr               True        2.41
# 58          bwr              bwr               True        2.41
# 59          bwr              bwr               True        2.41
# 60          bwr              bwr               True        2.41
# 61          bwr              bwr               True        2.41
# 62          bwr              bwr               True        2.10
# 63          bwr              pwr              False        2.10
# 64          bwr              bwr               True        2.10
# 65          bwr              bwr               True        2.10
# 66          bwr              bwr               True        1.60
# 67          bwr              bwr               True        2.10
# 68          bwr              bwr               True        2.10
# 69          bwr              bwr               True        2.10
# 70          bwr              bwr               True        2.10
# 72          bwr              bwr               True        2.10
# 74          bwr              bwr               True        2.10
# 76          bwr              bwr               True        2.10
# 78          bwr              bwr               True        1.60
# 303         bwr              bwr               True        3.00
# 374         pwr              bwr              False        3.13
# 375         pwr              bwr              False        3.13
# 376         pwr              bwr              False        3.13
# 378         pwr              bwr              False        3.13
# 380         pwr              bwr              False        3.13
# 382         pwr              bwr              False        3.13
# 384         pwr              bwr              False        3.13
# 386         pwr              bwr              False        3.13
# 387         pwr              bwr              False        3.13
# 388         pwr              bwr              False        3.13
# 390         pwr              bwr              False        3.13
# 392         pwr              bwr              False        3.13
#
#      pred_Enrichment  Relative_Enrichment_Error   Burnup  pred_Burnup  \
# 54              5.23                   1.170124   4200.0      8683.04
# 55              4.57                   0.896266   5580.0      9758.61
# 56              5.11                   1.120332   6080.0      9304.01
# 57              4.40                   0.825726   6640.0     11427.93
# 58              5.05                   1.095436   8140.0     13912.97
# 59              4.23                   0.755187   8260.0     11307.48
# 60              4.57                   0.896266   8320.0     13478.85
# 61              5.11                   1.120332   8640.0     13992.11
# 62              4.40                   1.095238   8850.0     17668.74
# 63              5.48                   1.609524   8930.0     21793.78
# 64              5.05                   1.404762   9140.0     17118.70
# 65              5.11                   1.433333   9440.0     19593.53
# 66              4.40                   1.750000   9800.0     19250.15
# 67              4.57                   1.176190  10280.0     19250.15
# 68              4.40                   1.095238  10510.0     19250.15
# 69              5.11                   1.433333  10540.0     19593.53
# 70              4.57                   1.176190  10570.0     19250.15
# 72              4.57                   1.176190  10660.0     19250.15
# 74              5.11                   1.433333  11920.0     21847.13
# 76              4.40                   1.095238  12700.0     21745.58
# 78              2.73                   0.706250  14040.0     20277.55
# 303             5.23                   0.743333  57400.0     64060.15
# 374             5.11                   0.632588  19254.0     31029.09
# 375             5.11                   0.632588  20060.0     31029.09
# 376             5.11                   0.632588  20628.0     33252.52
# 378             5.11                   0.632588  23557.0     39461.41
# 380             5.11                   0.632588  23715.0     39461.41
# 382             5.11                   0.632588  23953.0     43096.56
# 384             5.11                   0.632588  23988.0     39461.41
# 386             5.11                   0.632588  24250.0     43096.56
# 387             5.11                   0.632588  24313.0     43096.56
# 388             5.11                   0.632588  24532.0     39461.41
# 390             5.11                   0.632588  24693.0     39461.41
# 392             5.11                   0.632588  24849.0     39461.41
#
#      Relative_Burnup_Error           OrigenReactor pred_OrigenReactor  \
# 54                1.067390        Garigliano-1_BWR           abb8x8-1
# 55                0.748855        Garigliano-1_BWR            ge7x7-0
# 56                0.530265        Garigliano-1_BWR      atrium10x10-9
# 57                0.721074        Garigliano-1_BWR            ge7x7-0
# 58                0.709210        Garigliano-1_BWR           svea64-1
# 59                0.368944        Garigliano-1_BWR      atrium10x10-9
# 60                0.620054        Garigliano-1_BWR            ge7x7-0
# 61                0.619457        Garigliano-1_BWR      atrium10x10-9
# 62                0.996468        Garigliano-1_BWR            ge7x7-0
# 63                1.440513        Garigliano-1_BWR             s18x18
# 64                0.872943        Garigliano-1_BWR           svea64-1
# 65                1.075586        Garigliano-1_BWR      atrium10x10-9
# 66                0.964301        Garigliano-1_BWR            ge7x7-0
# 67                0.872583        Garigliano-1_BWR            ge7x7-0
# 68                0.831603        Garigliano-1_BWR            ge7x7-0
# 69                0.858969        Garigliano-1_BWR      atrium10x10-9
# 70                0.821206        Garigliano-1_BWR            ge7x7-0
# 72                0.805830        Garigliano-1_BWR            ge7x7-0
# 74                0.832813        Garigliano-1_BWR      atrium10x10-9
# 76                0.712250        Garigliano-1_BWR            ge7x7-0
# 78                0.444270        Garigliano-1_BWR           svea64-1
# 303               0.116030       Quad Cities-1_BWR           abb8x8-1
# 374               0.611566  Trino Vercellese-1_PWR      atrium10x10-9
# 375               0.546814  Trino Vercellese-1_PWR      atrium10x10-9
# 376               0.612009  Trino Vercellese-1_PWR      atrium10x10-9
# 378               0.675146  Trino Vercellese-1_PWR      atrium10x10-9
# 380               0.663985  Trino Vercellese-1_PWR      atrium10x10-9
# 382               0.799213  Trino Vercellese-1_PWR      atrium10x10-9
# 384               0.645048  Trino Vercellese-1_PWR      atrium10x10-9
# 386               0.777178  Trino Vercellese-1_PWR      atrium10x10-9
# 387               0.772573  Trino Vercellese-1_PWR      atrium10x10-9
# 388               0.608569  Trino Vercellese-1_PWR      atrium10x10-9
# 390               0.598081  Trino Vercellese-1_PWR      atrium10x10-9
# 392               0.588048  Trino Vercellese-1_PWR      atrium10x10-9
#
#        MaxLogLL
# 54    -8.741122
# 55    11.544400
# 56    10.778134
# 57    -8.061510
# 58    23.738365
# 59    11.403446
# 60    23.983706
# 61     3.973372
# 62  -449.234902
# 63  -516.102948
# 64  -491.230270
# 65  -407.161465
# 66  -557.013513
# 67  -406.768373
# 68  -364.540287
# 69  -357.078066
# 70  -343.471538
# 72  -405.010821
# 74  -375.214868
# 76  -373.852508
# 78  -376.521878
# 303 -650.172189
# 374 -305.349660
# 375 -280.085416
# 376 -322.045123
# 378 -289.601189
# 380 -298.673021
# 382 -463.506313
# 384 -356.795039
# 386 -527.044231
# 387 -465.490489
# 388 -307.556994
# 390 -349.871603
# 392 -269.413317

# %% [markdown]
# # Max Log LL

# %%
print(dfs['unc0']['MaxLogLL'].describe())
print(dfs['unc3']['MaxLogLL'].describe())
# Out:
# count     505.000000
# mean     -134.927067
# std       246.620348
# min     -2554.382504
# 25%      -136.777791
# 50%       -50.368502
# 75%       -18.304648
# max        64.665774
# Name: MaxLogLL, dtype: float64
# count    490.000000
# mean      10.182512
# std       23.947474
# min     -130.126567
# 25%       -3.514626
# 50%        3.204138
# 75%       21.907521
# max       98.435790
# Name: MaxLogLL, dtype: float64

# %% [markdown]
# # Nuclide Contributions to LL

# %%
nuc29 = ['am241', 'am242m', 'am243', 
         'cm242', 'cm244', 
         'cs134', 'cs137', 
         'eu154', 
         'nd143', 'nd144', 'nd145', 'nd146', 'nd148', 'nd150',
         'np237', 
         'pu238', 'pu239', 'pu240', 'pu241', 'pu242',
         'sm147', 'sm149', 'sm150', 'sm151', 'sm152',
         'u234', 'u235', 'u236', 'u238']

# %%
logpdf_df.sample(10)
# Out:
#                                       am241    am242m      am243      cm242  \
# MON-1|MTB099|A1|S4                      NaN       NaN        NaN   5.701263
# TAK-3|NT3G23|SF95|5                1.720071  8.762390   0.967821   6.611183
# GAR-1|A-106|E5|1                   6.209387       NaN -66.975933   6.125592
# TVC-1|509-032|E11|4                     NaN       NaN        NaN        NaN
# YNK-1|E6|NW-A1|T-162                    NaN       NaN        NaN        NaN
# MIH-3|JPNNM3SFA3|H13|87C07         0.595275  8.369913   4.287629  10.788233
# YNK-1|F4|C-F6|G-117                     NaN       NaN        NaN        NaN
# KAL-1|623|312|28                        NaN       NaN   7.907200        NaN
# VAN-2|EF05|WZR0058|E58-793       -47.640097       NaN  -3.266326        NaN
# GOS-1|1701|16B05|GU3' (Cycle 18)   2.009930  9.069915  -3.502505   8.815362
#
#                                       cm244     cs134     cs137     eu154  \
# MON-1|MTB099|A1|S4                      NaN       NaN       NaN       NaN
# TAK-3|NT3G23|SF95|5                2.235671  2.702204  1.782535  5.840749
# GAR-1|A-106|E5|1                  -1.230478       NaN       NaN       NaN
# TVC-1|509-032|E11|4                     NaN       NaN       NaN       NaN
# YNK-1|E6|NW-A1|T-162                    NaN       NaN       NaN       NaN
# MIH-3|JPNNM3SFA3|H13|87C07         0.831596  2.788992  0.876751  4.072577
# YNK-1|F4|C-F6|G-117                     NaN       NaN       NaN       NaN
# KAL-1|623|312|28                   9.139225       NaN       NaN       NaN
# VAN-2|EF05|WZR0058|E58-793       -43.757355  3.936822 -2.828296  3.090053
# GOS-1|1701|16B05|GU3' (Cycle 18)   2.110662  4.166690  1.483594  4.214821
#
#                                      nd143     nd144  ...      pu242  \
# MON-1|MTB099|A1|S4                     NaN       NaN  ...  -8.450708
# TAK-3|NT3G23|SF95|5               2.056807  2.214982  ...  -2.604896
# GAR-1|A-106|E5|1                       NaN       NaN  ... -73.914040
# TVC-1|509-032|E11|4                    NaN       NaN  ...  -3.804107
# YNK-1|E6|NW-A1|T-162                   NaN       NaN  ...   2.500148
# MIH-3|JPNNM3SFA3|H13|87C07        2.152434  0.476977  ...   1.708635
# YNK-1|F4|C-F6|G-117                    NaN       NaN  ...   5.077542
# KAL-1|623|312|28                       NaN       NaN  ...   1.764155
# VAN-2|EF05|WZR0058|E58-793       -1.176763 -3.229547  ...   0.138483
# GOS-1|1701|16B05|GU3' (Cycle 18)  1.889224  1.231874  ...   0.838122
#
#                                      sm147     sm149     sm150     sm151  \
# MON-1|MTB099|A1|S4                     NaN       NaN       NaN       NaN
# TAK-3|NT3G23|SF95|5                    NaN       NaN       NaN       NaN
# GAR-1|A-106|E5|1                       NaN       NaN       NaN       NaN
# TVC-1|509-032|E11|4                    NaN       NaN       NaN       NaN
# YNK-1|E6|NW-A1|T-162                   NaN       NaN       NaN       NaN
# MIH-3|JPNNM3SFA3|H13|87C07             NaN       NaN       NaN       NaN
# YNK-1|F4|C-F6|G-117                    NaN       NaN       NaN       NaN
# KAL-1|623|312|28                       NaN       NaN       NaN       NaN
# VAN-2|EF05|WZR0058|E58-793        3.208970  6.564944  2.018584  3.989921
# GOS-1|1701|16B05|GU3' (Cycle 18)  3.666432 -0.504183  2.090607  5.624280
#
#                                      sm152       u234      u235      u236  \
# MON-1|MTB099|A1|S4                     NaN -63.733032 -0.926910  1.154729
# TAK-3|NT3G23|SF95|5                    NaN  -3.870009 -0.733959  0.516318
# GAR-1|A-106|E5|1                       NaN        NaN       NaN       NaN
# TVC-1|509-032|E11|4                    NaN  -2.545652 -0.972570  0.693521
# YNK-1|E6|NW-A1|T-162                   NaN -37.003867 -3.585351 -0.147187
# MIH-3|JPNNM3SFA3|H13|87C07             NaN        NaN -1.185216       NaN
# YNK-1|F4|C-F6|G-117                    NaN -34.473449 -1.304830  1.046660
# KAL-1|623|312|28                       NaN -20.860849 -3.054663 -0.053072
# VAN-2|EF05|WZR0058|E58-793        0.208491   3.175965 -4.955366 -7.924703
# GOS-1|1701|16B05|GU3' (Cycle 18)  3.528672  -2.750877  0.171821  0.278416
#
#                                       u238
# MON-1|MTB099|A1|S4               -4.796544
# TAK-3|NT3G23|SF95|5              -4.768950
# GAR-1|A-106|E5|1                       NaN
# TVC-1|509-032|E11|4              -4.787017
# YNK-1|E6|NW-A1|T-162             -4.780078
# MIH-3|JPNNM3SFA3|H13|87C07       -4.778754
# YNK-1|F4|C-F6|G-117              -4.785268
# KAL-1|623|312|28                 -4.783016
# VAN-2|EF05|WZR0058|E58-793             NaN
# GOS-1|1701|16B05|GU3' (Cycle 18) -4.753364
#
# [10 rows x 29 columns]

# %%
for nuc in nuc29:
    desc = logpdf_df[nuc].describe()
    print(desc[['count', 'mean', 'std', 'min', 'max']])
# Out:
# count    237.000000
# mean     -43.111645
# std       97.121443
# min     -794.506648
# max        7.443631
# Name: am241, dtype: float64
# count    110.000000
# mean     -28.865569
# std       54.989217
# min     -186.267401
# max       13.108325
# Name: am242m, dtype: float64
# count    203.000000
# mean      -7.205421
# std       17.722737
# min     -101.038273
# max        9.315329
# Name: am243, dtype: float64
# count    214.000000
# mean      -7.635268
# std       36.916614
# min     -302.590970
# max       18.925809
# Name: cm242, dtype: float64
# count    269.000000
# mean     -14.969502
# std       38.596167
# min     -175.276748
# max       17.242042
# Name: cm244, dtype: float64
# count    113.000000
# mean     -29.159047
# std       56.604572
# min     -180.668807
# max        9.725492
# Name: cs134, dtype: float64
# count    185.000000
# mean      -4.224876
# std       11.265662
# min      -70.572595
# max        4.037617
# Name: cs137, dtype: float64
# count    100.000000
# mean     -23.055338
# std       42.402957
# min     -166.955348
# max        8.000693
# Name: eu154, dtype: float64
# count    162.000000
# mean      -0.469545
# std        4.876645
# min      -34.603993
# max        4.332357
# Name: nd143, dtype: float64
# count    113.000000
# mean      -2.364490
# std        5.448434
# min      -26.207981
# max        4.250153
# Name: nd144, dtype: float64
# count    162.000000
# mean      -0.117741
# std        4.182464
# min      -24.753479
# max        4.682238
# Name: nd145, dtype: float64
# count    139.000000
# mean      -1.329124
# std        6.099702
# min      -42.777175
# max        4.941561
# Name: nd146, dtype: float64
# count    275.000000
# mean       0.854071
# std        4.095428
# min      -25.352834
# max        5.758005
# Name: nd148, dtype: float64
# count    121.000000
# mean       1.319944
# std        4.246841
# min      -24.206537
# max        6.308669
# Name: nd150, dtype: float64
# count    155.000000
# mean     -12.424203
# std       36.978165
# min     -188.609049
# max        4.619791
# Name: np237, dtype: float64
# count    369.000000
# mean     -14.162796
# std       43.659086
# min     -194.806386
# max        8.195863
# Name: pu238, dtype: float64
# count    505.000000
# mean      -3.369474
# std        5.209976
# min      -33.704808
# max        1.911818
# Name: pu239, dtype: float64
# count    505.000000
# mean     -11.437482
# std       13.556628
# min     -117.802634
# max        4.294194
# Name: pu240, dtype: float64
# count    504.000000
# mean      -8.512080
# std       33.385423
# min     -180.065679
# max        8.110859
# Name: pu241, dtype: float64
# count    505.000000
# mean      -7.916903
# std       19.259616
# min     -152.675397
# max       10.005040
# Name: pu242, dtype: float64
# count     97.000000
# mean     -20.839578
# std       42.800762
# min     -206.303220
# max        3.820269
# Name: sm147, dtype: float64
# count     97.000000
# mean     -15.117409
# std       55.419960
# min     -383.394941
# max        8.462901
# Name: sm149, dtype: float64
# count    97.000000
# mean     -0.425869
# std       9.240630
# min     -80.923403
# max       3.859556
# Name: sm150, dtype: float64
# count     97.000000
# mean      -3.566256
# std       47.526945
# min     -454.699270
# max        6.832928
# Name: sm151, dtype: float64
# count    97.000000
# mean      1.003802
# std       9.578594
# min     -87.080087
# max       4.641632
# Name: sm152, dtype: float64
# count    355.000000
# mean     -25.835692
# std       40.133546
# min     -582.076781
# max        3.907920
# Name: u234, dtype: float64
# count    479.000000
# mean      -3.930115
# std        8.693537
# min     -139.049420
# max        5.025434
# Name: u235, dtype: float64
# count    462.000000
# mean      -2.728862
# std        6.948822
# min      -40.895068
# max        3.408294
# Name: u236, dtype: float64
# count    433.000000
# mean      -4.797613
# std        0.093966
# min       -6.055746
# max       -4.740235
# Name: u238, dtype: float64

# %% [markdown]
# # Look at ratio values for a single prediction

# %%
sim_id = 'VAN-2|EF05|WZR0058|E58-88'
pred_id = 43225
preds.loc[preds['sim_idx']==sim_id, to_print]
# Out:
#                        sim_idx  pred_idx  pred_CoolingTime  AvgPowerDensity  \
# 418  VAN-2|EF05|WZR0058|E58-88    261683         1945.4721             25.0
#
#     ReactorType pred_ReactorType  ReactorType_Score  Enrichment  \
# 418         pwr              pwr               True         4.5
#
#      pred_Enrichment  Relative_Enrichment_Error   Burnup  pred_Burnup  \
# 418             5.39                   0.197778  43520.0     40607.34
#
#      Relative_Burnup_Error    OrigenReactor pred_OrigenReactor   MaxLogLL
# 418               0.066927  Vandellos-2_PWR            ce14x14 -53.440264

# %%
y_mes = sfco.loc[sfco.index == sim_id].squeeze().drop(lbls)
y_sim = XY.loc[XY.index == pred_id].squeeze().drop(lbls+nonlbls)
y_logpdf = logpdf_df.loc[logpdf_df.index == sim_id].squeeze()
df = pd.DataFrame([y_mes, y_sim])
df.loc['Abs Diff'] = np.abs(df.loc[pred_id] - df.loc[sim_id])
df.loc['% Diff'] = df.loc['Abs Diff'] * 100 / df.loc[sim_id]
df.loc['LogPDF'] = y_logpdf

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)
df
# Out:
#                                am241    am242m     am243     cm242      cm244  \
# VAN-2|EF05|WZR0058|E58-88   0.252000  0.000000  0.090100  0.000000   0.016500
# 43225                       0.356800  0.000905  0.084320  0.000005   0.021330
# Abs Diff                    0.104800  0.000905  0.005780  0.000005   0.004830
# % Diff                     41.587302       inf  6.415094       inf  29.272727
# LogPDF                    -23.891769       NaN  3.952035       NaN  -7.684340
#
#                                cs134      cs137      eu154     nd143  \
# VAN-2|EF05|WZR0058|E58-88   0.018400   1.430000   0.016600  1.020000
# 43225                       0.015460   1.154000   0.014720  0.925500
# Abs Diff                    0.002940   0.276000   0.001880  0.094500
# % Diff                     15.978261  19.300699  11.325301  9.264706
# LogPDF                      1.498427  -0.087854   2.777426  1.023434
#
#                               nd144     nd145     nd146      nd148      nd150  \
# VAN-2|EF05|WZR0058|E58-88  1.650000  0.842000  0.852000   0.484000   0.235000
# 43225                      1.491000  0.774400  0.770200   0.408100   0.189500
# Abs Diff                   0.159000  0.067600  0.081800   0.075900   0.045500
# % Diff                     9.636364  8.028504  9.600939  15.681818  19.361702
# LogPDF                     1.517373  2.040362  2.205196   2.022781   0.494180
#
#                                np237      pu238      pu239      pu240  \
# VAN-2|EF05|WZR0058|E58-88   0.610000   0.268000   6.140000   2.400000
# 43225                       0.482600   0.183700   4.826000   1.581000
# Abs Diff                    0.127400   0.084300   1.314000   0.819000
# % Diff                     20.885246  31.455224  21.400651  34.125000
# LogPDF                      2.546734  -4.827878  -0.356085 -34.313905
#
#                                pu241      pu242     sm147      sm149  \
# VAN-2|EF05|WZR0058|E58-88   1.130000   0.556000  0.275000   0.003390
# 43225                       0.938900   0.472900  0.277700   0.002967
# Abs Diff                    0.191100   0.083100  0.002700   0.000423
# % Diff                     16.911504  14.946043  0.981818  12.477876
# LogPDF                      1.952183  -6.366853  2.324237   5.403919
#
#                               sm150      sm151     sm152      u234       u235  \
# VAN-2|EF05|WZR0058|E58-88  0.331000   0.014400  0.125000  0.237000  12.900000
# 43225                      0.307400   0.012120  0.114600  0.230200  13.390000
# Abs Diff                   0.023600   0.002280  0.010400  0.006800   0.490000
# % Diff                     7.129909  15.833333  8.320000  2.869198   3.798450
# LogPDF                     2.741665   5.695389  3.777571  3.335053 -17.739232
#
#                                u236   u238
# VAN-2|EF05|WZR0058|E58-88  5.510000    0.0
# 43225                      5.313000  934.0
# Abs Diff                   0.197000  934.0
# % Diff                     3.575318    inf
# LogPDF                    -3.480312    NaN
